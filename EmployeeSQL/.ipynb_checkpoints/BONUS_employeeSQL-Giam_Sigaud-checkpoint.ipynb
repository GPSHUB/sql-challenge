# %%
# Import Dependencies
import pandas as pd
import sqlalchemy 
import pprint
import matplotlib.pyplot as plt
import numpy as np
import psycopg2

# %%
# Create login 
username = "postgres"
password = "Buddhah1pst@"

# %%
# Create engine & Connect
from sqlalchemy import create_engine
engine = create_engine (f"postgresql://{username}:{password}@localhost:5432/HW09SQL")
connection = engine.connect()

# %%
#Import from SQL, employees table & rename emp_title_id column to merge with other tables
employees = pd.read_sql('select * from employees', connection, parse_dates=['birth_date', 'hire_date'])
employees_new = employees.rename(columns={'emp_title_id': 'title_id'})
employees_new.head()
# Out:
#    emp_no title_id birth_date  first_name  last_name sex  hire_date
# 0  473302    s0001 1953-07-25    Hideyuki   Zallocco   M 1990-04-28
# 1  475053    e0002 1954-11-18       Byong  Delgrande   F 1991-09-07
# 2   57444    e0002 1958-01-30       Berry       Babb   F 1992-03-21
# 3  421786    s0001 1957-09-28       Xiong   Verhoeff   M 1987-11-26
# 4  282238    e0003 1952-10-28  Abdelkader    Baumann   F 1991-01-18

# %%
#Import from SQL, salaries table
salaries = pd.read_sql('select * from salaries', connection)
salaries.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
#Import from SQL, title tables
titles = pd.read_sql('select * from titles', connection)
titles.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
#Create merged df of employees & titles
emp_titles = pd.merge(employees_new, titles, on='title_id', how='inner')
emp_titles.head()
# Out:
#    emp_no title_id birth_date  first_name   last_name sex  hire_date  title
# 0  473302    s0001 1953-07-25    Hideyuki    Zallocco   M 1990-04-28  Staff
# 1  421786    s0001 1957-09-28       Xiong    Verhoeff   M 1987-11-26  Staff
# 2  273487    s0001 1957-04-14   Christoph     Parfitt   M 1991-06-28  Staff
# 3  246449    s0001 1958-03-23       Subbu  Bultermann   F 1988-03-25  Staff
# 4   48085    s0001 1964-01-19  Venkatesan        Gilg   M 1993-06-28  Staff

# %%
# Merge employees + titles with salaries
emp_titles_sal = pd.merge(emp_titles, salaries, on="emp_no")
emp_titles_sal.head()
# Out:
#    emp_no title_id birth_date  first_name   last_name sex  hire_date  title  \
# 0  473302    s0001 1953-07-25    Hideyuki    Zallocco   M 1990-04-28  Staff
# 1  421786    s0001 1957-09-28       Xiong    Verhoeff   M 1987-11-26  Staff
# 2  273487    s0001 1957-04-14   Christoph     Parfitt   M 1991-06-28  Staff
# 3  246449    s0001 1958-03-23       Subbu  Bultermann   F 1988-03-25  Staff
# 4   48085    s0001 1964-01-19  Venkatesan        Gilg   M 1993-06-28  Staff
#
#    salary
# 0   40000
# 1   40000
# 2   56087
# 3   87084
# 4   63016

# %%
# Limit columns for bar Chart
emp_titles_sal_df = emp_titles_sal[['title', 'salary']]
emp_titles_sal_df.head()
# Out:
#    title  salary
# 0  Staff   40000
# 1  Staff   40000
# 2  Staff   56087
# 3  Staff   87084
# 4  Staff   63016

# %%
# group titles and deliver average salary
e_t_s_grouped = emp_titles_sal_df.groupby("title").mean()
pd.options.display.float_format='${:,.2f}'.format
e_t_s_grouped = e_t_s_grouped.reset_index()
e_t_s_grouped
# Out:
#                 title     salary
# 0  Assistant Engineer $48,564.43
# 1            Engineer $48,535.34
# 2             Manager $51,531.04
# 3     Senior Engineer $48,506.80
# 4        Senior Staff $58,550.17
# 5               Staff $58,465.38
# 6    Technique Leader $48,582.90

# %%
# Set x_axis, y_axis & Tick Locations
x_axis = e_t_s_grouped["title"]
ticks = np.arange(len(x_axis))
y_axis = e_t_s_grouped["salary"]
 
# Create Bar Chart Based on Above Data
plt.bar(x_axis, y_axis, align="center", alpha=.6, color=["red", "green", "lightblue", "maroon", "gray", "yellow", "navy"], edgecolor=['black'])
# Create Ticks for Bar Chart's x_axis
plt.xticks(ticks, x_axis, rotation="vertical")

# Set Labels & Title
plt.ylabel("Salaries ($)")
plt.xlabel("Titles")
plt.title("Average Employee Salary by Title")

# Save Figure
plt.savefig("Images/Average_Salary_By_Title.png")

# Show plot
plt.show()

# %%
# My ID is April Fool's Day
my_id = emp_titles_sal.loc[emp_titles_sal['emp_no'] == 499942] 
my_id
# Out:
#         emp_no title_id birth_date first_name last_name sex  hire_date  \
# 287532  499942    e0004 1963-01-10      April  Foolsday   F 1997-02-10
#
#                    title  salary
# 287532  Technique Leader   40000
